# %%
# !pip install ragas langchain-openai sentence_transformers xmltodict python-dotenv langchain_groq rapidfuzz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.3/178.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.1/414.1 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata
import pandas as pd
from langchain_community.document_loaders import PubMedLoader
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from ragas.testset import TestsetGenerator
# from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_groq import ChatGroq
from ragas.llms import LangchainLLMWrapper

# %%
data_generation_model= ChatGroq(temperature=0.8, model_name="llama3-70b-8192" ,api_key="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")
data_generation_model=LangchainLLMWrapper(data_generation_model)

# %%
critic_model= ChatGroq(temperature=0.8, model_name="llama3-70b-8192" ,api_key="{Add API HERE}")
critic_model=LangchainLLMWrapper(critic_model)

# %%
model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
embeddings = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
# Out:
# <ipython-input-7-bdf9e6037ce1>:4: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceBgeEmbeddings(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# !pip install --upgrade urllib3

# %%
loader = PubMedLoader("cancer", load_max_docs=5)

# %%
loader

# %%
documents = loader.load()
documents
# Out:
# Too Many Requests, waiting for 0.20 seconds...
# Too Many Requests, waiting for 0.40 seconds...
# ...

# %%
generator = TestsetGenerator.from_langchain(
    data_generation_model,
    critic_model,
    embeddings
)

# %%
generator = TestsetGenerator(llm= data_generation_model, embedding_model=embeddings)
dataset = generator.generate_with_langchain_docs(documents, testset_size=100)
# Out:
# ...
# Applying CustomNodeFilter:   0%|          | 0/5 [00:00<?, ?it/s]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# Generating Samples:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-11-8adfd6bc8d6c> in <cell line: 0>()
#       1 generator = TestsetGenerator(llm= data_generation_model, embedding_model=embeddings)
# ----> 2 dataset = generator.generate_with_langchain_docs(documents, testset_size=100)
#
# /usr/local/lib/python3.11/dist-packages/ragas/testset/synthesizers/generate.py in generate_with_langchain_docs(self, documents, testset_size, transforms, transforms_llm, transforms_embedding_model, query_distribution, run_config, callbacks, with_debugging_logs, raise_exceptions)
#     186         self.knowledge_graph = kg
#     187
# ...

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  What is the efect of Plantago lanceolata extra...
# 1  What is the role of U87-MG in the study of the...
# 2  What is the role of AMPK-p53-p21 in arginine d...
# 3  What makes colorectal cancer cells susceptible...
# 4  What are chimeric antigen receptors and how do...
# 5  What are the impakt of immunotherpy on kidney ...
# 6  What are the barriers to enrolling Black and A...
# 7  What about Black people and african americans ...
# 8  What is the importance of accurate GFR assessm...
# 9                   What GFR do for cancer patients?
#
#                                   reference_contexts  \
# 0  [Plantago lanceolata\nAlzheimer's disease is l...
# 1  [Plantago lanceolata\nAlzheimer's disease is l...
# 2  [Metabolic reprogramming is a hallmark of canc...
# 3  [Metabolic reprogramming is a hallmark of canc...
# 4  [The landscape of cancer survival has been pos...
# 5  [The landscape of cancer survival has been pos...
# ...
